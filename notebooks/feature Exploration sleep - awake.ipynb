# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import seaborn as sns
sns.set()
import ipywidgets

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_excel('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\binomial_target.xlsx')
X = df.iloc[:,:-1]

# %%
X = df.iloc[:,:-1]
df.head()
# Out:
#    mean_eeg_1   std_eeg_1    min_eeg_1    max_eeg_1  25%_eeg_1  50%_eeg_1  \
# 0    0.174354   24.407860  -115.083031    73.697525 -12.675723  -0.106948
# 1    0.250711   18.476830   -52.644550    79.843292 -11.530433  -0.608202
# 2   -0.433507   13.916072   -59.793839    40.666286  -9.609270  -0.077825
# 3    6.167094  528.967346 -5057.264160  2870.531006 -74.583311 -15.299914
# 4    0.490618   64.609421  -322.801331   340.338409 -39.432262  -1.159150
#
#    75%_eeg_1  mean_eeg_2    std_eeg_2     min_eeg_2 ...  50%_accelerometer_y  \
# 0  13.813232    0.144853    24.738373    -66.343269 ...             0.000004
# 1  10.381102    0.661373    25.693821    -73.486809 ...             0.000030
# 2   8.939811   -0.322502    23.724653    -55.826244 ...            -0.000003
# 3  56.770740   25.525339  2355.349854 -18426.763672 ...             0.000064
# 4  39.119254  -14.053326   532.793823  -2070.334473 ...             0.000063
#
# ...

# %%
def plot_vardensity_awake(df_):
    df = df_.copy()
    awake = df.loc[df.Y==0]
    sleep = df.loc[df.Y !=0]
    for k in df.iloc[:, :-1].columns:
        fig, ax = plt.subplots(figsize=(20,9))
        sns.kdeplot(awake[k], shade=True, color="r")
        sns.kdeplot(sleep[k], shade=True, color="b")
        plt.figure()

# %%
plot_vardensity_awake(df.iloc[:, -8:])

# %%
plot_vardensity_awake(df)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
scaler = StandardScaler()

# %%
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)
df_scaled = X_scaled
df_scaled["Y"] = df["Y"]

# %%
plot_vardensity_awake(df.iloc[:, -8:])
# as it should standaritisation does not change distribution shape
