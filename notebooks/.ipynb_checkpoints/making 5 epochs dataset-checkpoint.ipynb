# %%
import pandas as pd
import numpy as np

# %%
# %load "C:\\Users\\i053131\Desktop\\Epilepsie\\Dreem\\src\\data\\reshape_5.py"
def reshape_5(df):
	#df = d.copy()
	if (df.shape[0] <5): 
		return df
	r = df.shape[0]
	c = df.shape[1]
	newColumns = []
	for i in range(0, 5):
		for colName in df.columns:
			newColumns.append(colName + str(i+1))
	result = pd.DataFrame(columns = newColumns, data = np.zeros((r, c*5)))
	for i in range(2, r-2):
		result.iloc[i,0:c]= df.iloc[i-2, :].values
		result.iloc[i,c:c*2]= df.iloc[i-1, :].values
		result.iloc[i,c*2:c*3]= df.iloc[i, :].values
		result.iloc[i,c*3:c*4]= df.iloc[i+1, :].values
		result.iloc[i,c*4:c*5]= df.iloc[i+2, :].values
	
	
	return result

# %%
naif = pd.read_excel('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\featuresTrain.xlsx')

# %%
eeg = pd.read_excel('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\spectrogram_eeg_features30Train.xlsx')
acc = pd.read_excel('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\acc_featuresTrain.xlsx')
pulse = pd.read_csv('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\pulse_featuresTrain.csv')
pulse = pulse.iloc[:, 1:]  
eeg.drop(columns=["eeg1_Above100Hz0", "eeg2_Above100Hz0", "eeg3_Above100Hz0", "eeg4_Above100Hz0"], inplace=True)

# %%
df = pd.concat([eeg, acc, pulse, naif], axis=1)

# %%
train = df.iloc[0:int(df.shape[0]*0.8), :]
test = df.iloc[int(df.shape[0]*0.8):, :]

# %%
train5 = reshape_5(train.iloc[:,:-1])
train5["Y"]= train.iloc[:,-1]
train5.head()
# Out:
#    eeg1_Delta01  eeg1_Theta01  eeg1_Alpha01  eeg1_Beta01  eeg1_Gamma01  \
# 0      0.000000      0.000000      0.000000     0.000000      0.000000
# 1      0.000000      0.000000      0.000000     0.000000      0.000000
# 2  15067.384836    791.799053    526.234402   238.067846      8.873436
# 3   6194.997941    870.974146    724.313661   222.860622     12.592876
# 4   4574.792936    498.015318    548.223114   169.697156     11.446063
#
#    eeg2_Delta01  eeg2_Theta01  eeg2_Alpha01  eeg2_Beta01  eeg2_Gamma01 ...  \
# 0      0.000000      0.000000      0.000000     0.000000      0.000000 ...
# 1      0.000000      0.000000      0.000000     0.000000      0.000000 ...
# 2  15539.011891   1211.021770    592.088885   258.187675      9.665757 ...
# 3  14985.783284   1431.564131    912.804498   225.851998     10.602561 ...
# 4  13470.917151   1351.801779    653.645947   206.578801      9.582789 ...
#
#    50%_accelerometer_y5  75%_accelerometer_y5  mean_accelerometer_z5  \
# ...

# %%
train5.drop([0, 1], inplace=True)
train5.drop([train5.shape[0]-1, train5.shape[0]-2], inplace=True)
train5.head()
# Out:
#     eeg1_Delta01  eeg1_Theta01  eeg1_Alpha01  eeg1_Beta01  eeg1_Gamma01  \
# 2   15067.384836    791.799053    526.234402   238.067846      8.873436
# 3    6194.997941    870.974146    724.313661   222.860622     12.592876
# 4    4574.792936    498.015318    548.223114   169.697156     11.446063
# 5  317175.991019  14574.874852  19000.159158   892.029313     18.739333
# 6   58746.615386   7275.947515  15771.361858   664.287392     16.583832
#
#    eeg2_Delta01  eeg2_Theta01   eeg2_Alpha01   eeg2_Beta01  eeg2_Gamma01 ...  \
# 2  1.553901e+04  1.211022e+03     592.088885    258.187675      9.665757 ...
# 3  1.498578e+04  1.431564e+03     912.804498    225.851998     10.602561 ...
# 4  1.347092e+04  1.351802e+03     653.645947    206.578801      9.582789 ...
# 5  3.123085e+07  6.766067e+05  165130.691286  14969.208303    384.833126 ...
# 6  6.828195e+06  1.185932e+06  203716.821691  23404.834724    326.066719 ...
#
# ...

# %%
train5.to_csv('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\5Epochstrain.csv', index=False)

# %%
test5 = reshape_5(test.iloc[:,:-1])
test5["Y"]= test.iloc[:,-1].values
#train5["Y"]= train.iloc[:,-1]
test5.head()
# Out:
#     eeg1_Delta01  eeg1_Theta01  eeg1_Alpha01  eeg1_Beta01  eeg1_Gamma01  \
# 0       0.000000      0.000000      0.000000     0.000000      0.000000
# 1       0.000000      0.000000      0.000000     0.000000      0.000000
# 2  255762.626691   1887.916575    561.021031    45.619842      1.939967
# 3  294107.129532   1975.253455    704.557740    49.478179      1.986974
# 4  186704.295729   1381.383668    496.889427    51.750079      2.159550
#
#    eeg2_Delta01  eeg2_Theta01  eeg2_Alpha01  eeg2_Beta01  eeg2_Gamma01 ...  \
# 0      0.000000      0.000000      0.000000     0.000000      0.000000 ...
# 1      0.000000      0.000000      0.000000     0.000000      0.000000 ...
# 2  66503.188184   1427.790232    373.751537    37.807070      1.671914 ...
# 3  79407.658983   1712.473080    519.408900    47.016144      1.973182 ...
# 4  79202.970175   1187.998718    402.326770    41.406831      1.667569 ...
#
#    50%_accelerometer_y5  75%_accelerometer_y5  mean_accelerometer_z5  \
# ...

# %%
test5.drop([0, 1], inplace=True)
test5.drop([test5.shape[0]-1, test5.shape[0]-2], inplace=True)
test5.head()
# Out:
#     eeg1_Delta01  eeg1_Theta01  eeg1_Alpha01  eeg1_Beta01  eeg1_Gamma01  \
# 2  255762.626691   1887.916575    561.021031    45.619842      1.939967
# 3  294107.129532   1975.253455    704.557740    49.478179      1.986974
# 4  186704.295729   1381.383668    496.889427    51.750079      2.159550
# 5  193268.560354   2312.859286    685.268470    54.836992      1.972159
# 6  542475.415857   2632.156937    570.963802    70.557094      2.075757
#
#     eeg2_Delta01  eeg2_Theta01  eeg2_Alpha01  eeg2_Beta01  eeg2_Gamma01 ...  \
# 2   66503.188184   1427.790232    373.751537    37.807070      1.671914 ...
# 3   79407.658983   1712.473080    519.408900    47.016144      1.973182 ...
# 4   79202.970175   1187.998718    402.326770    41.406831      1.667569 ...
# 5   75963.089971   1895.347247    577.479308    46.352483      1.619584 ...
# 6  124776.803561   1635.052858    396.048336    43.170587      2.187199 ...
#
#    50%_accelerometer_y5  75%_accelerometer_y5  mean_accelerometer_z5  \
# ...

# %%
test5.to_csv('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\5EpochsTest.csv', index=False)

# %%
test5.columns
# Out:
# Index(['eeg1_Delta01', 'eeg1_Theta01', 'eeg1_Alpha01', 'eeg1_Beta01',
#        'eeg1_Gamma01', 'eeg2_Delta01', 'eeg2_Theta01', 'eeg2_Alpha01',
#        'eeg2_Beta01', 'eeg2_Gamma01',
#        ...
#        '50%_accelerometer_y5', '75%_accelerometer_y5', 'mean_accelerometer_z5',
#        'std_accelerometer_z5', 'min_accelerometer_z5', 'max_accelerometer_z5',
#        '25%_accelerometer_z5', '50%_accelerometer_z5', '75%_accelerometer_z5',
#        'Y'],
#       dtype='object', length=566)

# %%
(len(test.columns)-1)*5 + 1 == len(test5.columns)
# Out:
# True

# %%
naif = pd.read_excel('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\featuresTest.xlsx')
eeg = pd.read_excel('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\spectrogram_eeg_features30Test.xlsx')
acc = pd.read_excel('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\acc_featuresTest.xlsx')
pulse = pd.read_csv('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\pulse_featuresTest.csv')
pulse = pulse.iloc[:, 1:]  
eeg.drop(columns=["eeg1_Above100Hz0", "eeg2_Above100Hz0", "eeg3_Above100Hz0", "eeg4_Above100Hz0"], inplace=True)

df = pd.concat([eeg, acc, pulse, naif], axis=1)

# %%
valid = reshape_5(df)
valid.head()
# Out:
#     eeg1_Delta01  eeg1_Theta01  eeg1_Alpha01  eeg1_Beta01  eeg1_Gamma01  \
# 0       0.000000      0.000000      0.000000     0.000000      0.000000
# 1       0.000000      0.000000      0.000000     0.000000      0.000000
# 2   78425.727414   1355.065168    384.568129   173.690574      4.569997
# 3  447429.322990   7329.456547   3856.379961   419.380044     10.741931
# 4  235692.733542   5211.582786   1498.968464   207.741618      7.228800
#
#     eeg2_Delta01  eeg2_Theta01  eeg2_Alpha01  eeg2_Beta01  eeg2_Gamma01  \
# 0       0.000000      0.000000      0.000000     0.000000      0.000000
# 1       0.000000      0.000000      0.000000     0.000000      0.000000
# 2   76888.581911   2080.479270    788.406757   229.814792      5.613314
# 3  461429.927323   7850.591535   3672.605909   393.577136     10.474191
# 4  233555.970507   5343.406232   1527.508146   245.110652      7.960067
#
#            ...           25%_accelerometer_y5  50%_accelerometer_y5  \
# ...

# %%
valid.to_csv('C:\\Users\\i053131\\Desktop\\Epilepsie\\Dreem\\data\\interim\\5Epochsvalid.csv', index=False)

# %%
(len(df.columns))*5  == len(valid.columns)
# Out:
# True

# %%
valid.shape
# Out:
# (20592, 565)

# %%
df.shape
# Out:
# (20592, 113)
